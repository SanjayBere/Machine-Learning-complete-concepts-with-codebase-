# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#  reading the csv file 
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Univariate Analysis

# %%
# picking flower typewise rows and storing it in different dataframes
df_setosa = df.loc[df['species']=='setosa']
df_virginica = df.loc[df['species']=='virginica']
df_versicolor = df.loc[df['species']=='versicolor']

plt.plot( df_setosa['sepal_length'] ,  np.zeros_like(df_setosa['sepal_length']),'o' )
plt.plot( df_virginica['sepal_length'] , np.zeros_like(df_virginica['sepal_length']),'o' )
plt.plot( df_versicolor['sepal_length'] , np.zeros_like(df_versicolor['sepal_length']) ,'o')

plt.xlabel("Sepal_length")
plt.title("Univariate analysis")
# Out:
# Text(0.5, 1.0, 'Univariate analysis')

# %% [markdown]
# #### Description :
# - by looking to above graph , we can say that , versicolor and verginica can be separable a bit
# - but setosa and verginica are mixed so that they cant be separable easily

# %% [markdown]
# # Bivariate analysis

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# sns.FacetGrid(df,hue="species")
sns.jointplot(x="sepal_length" , y="petal_width" , data = df , kind="scatter" , hue="species")

# %%
# sns.FacetGrid(df,hue="species")
sns.jointplot(x="petal_length" , y="sepal_width" , data = df , kind="scatter" , hue="species")

# %%
# sns.FacetGrid(df,hue="species")
sns.jointplot(x="sepal_length" , y="petal_length" , data = df , kind="scatter" , hue="species")

# %%
# sns.FacetGrid(df,hue="species")
sns.jointplot(x="sepal_width" , y="petal_width" , data = df , kind="scatter" , hue="species")

# %% [markdown]
# # Multivariate analysis

# %%
sns.pairplot(df,hue="species" , kind='reg')
